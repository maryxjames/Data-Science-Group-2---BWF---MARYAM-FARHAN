# %% [markdown]
# # Task 13: Data manipulation with Pandas (indexing, selection, grouping)

# %%
#Load a DataFrame from a CSV file. Display the first and last five rows of the DataFrame.
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("World Largest Cities by Population 2024.csv")
data
# Out:
#      Unnamed: 0            City         Country  Population (2024)  \
# 0             0           Tokyo           Japan           37115035
# 1             1           Delhi           India           33807403
# 2             2        Shanghai           China           29867918
# 3             3           Dhaka      Bangladesh           23935652
# 4             4       Sao Paulo          Brazil           22806704
# ..          ...             ...             ...                ...
# 796         796       Bhavnagar           India             751493
# 797         797       Sheffield  United Kingdom             751303
# 798         798          Huambo          Angola             751297
# 799         799  Ribeirao Preto          Brazil             750174
# 800         800       Panzhihua           China             750036
#
#      Population (2023)  Growth Rate
# 0             37194105      -0.0021
# 1             32941309       0.0263
# 2             29210808       0.0225
# ...

# %%
data.head(5)
# Out:
#    Unnamed: 0       City     Country  Population (2024)  Population (2023)  \
# 0           0      Tokyo       Japan           37115035           37194105
# 1           1      Delhi       India           33807403           32941309
# 2           2   Shanghai       China           29867918           29210808
# 3           3      Dhaka  Bangladesh           23935652           23209616
# 4           4  Sao Paulo      Brazil           22806704           22619736
#
#    Growth Rate
# 0      -0.0021
# 1       0.0263
# 2       0.0225
# 3       0.0313
# 4       0.0083

# %%
data.tail(5)
# Out:
#      Unnamed: 0            City         Country  Population (2024)  \
# 796         796       Bhavnagar           India             751493
# 797         797       Sheffield  United Kingdom             751303
# 798         798          Huambo          Angola             751297
# 799         799  Ribeirao Preto          Brazil             750174
# 800         800       Panzhihua           China             750036
#
#      Population (2023)  Growth Rate
# 796             737128       0.0195
# 797             745876       0.0073
# 798             727641       0.0325
# 799             742115       0.0109
# 800             738495       0.0156

# %%
#Set a specific column as the index of the DataFrame.
data['Country']
# Out:
# 0               Japan
# 1               India
# 2               China
# 3          Bangladesh
# 4              Brazil
#             ...
# 796             India
# 797    United Kingdom
# 798            Angola
# 799            Brazil
# 800             China
# Name: Country, Length: 801, dtype: object

# %%
data.set_index('Country')
# Out:
#                 Unnamed: 0            City  Population (2024)  \
# Country
# Japan                    0           Tokyo           37115035
# India                    1           Delhi           33807403
# China                    2        Shanghai           29867918
# Bangladesh               3           Dhaka           23935652
# Brazil                   4       Sao Paulo           22806704
# ...                    ...             ...                ...
# India                  796       Bhavnagar             751493
# United Kingdom         797       Sheffield             751303
# Angola                 798          Huambo             751297
# Brazil                 799  Ribeirao Preto             750174
# China                  800       Panzhihua             750036
#
#                 Population (2023)  Growth Rate
# Country
# Japan                    37194105      -0.0021
# India                    32941309       0.0263
# China                    29210808       0.0225
# ...

# %%
#Select a specific column and display its values.
data['Population (2023)']
# Out:
# 0      37194105
# 1      32941309
# 2      29210808
# 3      23209616
# 4      22619736
#          ...
# 796      737128
# 797      745876
# 798      727641
# 799      742115
# 800      738495
# Name: Population (2023), Length: 801, dtype: int64

# %%
#Select multiple columns and display the resulting DataFrame
data.index
# Out:
# RangeIndex(start=0, stop=801, step=1)

# %%
data[['Country', 'Population (2023)','City']]
# Out:
#             Country  Population (2023)            City
# 0             Japan           37194105           Tokyo
# 1             India           32941309           Delhi
# 2             China           29210808        Shanghai
# 3        Bangladesh           23209616           Dhaka
# 4            Brazil           22619736       Sao Paulo
# ..              ...                ...             ...
# 796           India             737128       Bhavnagar
# 797  United Kingdom             745876       Sheffield
# 798          Angola             727641          Huambo
# 799          Brazil             742115  Ribeirao Preto
# 800           China             738495       Panzhihua
#
# [801 rows x 3 columns]

# %%
#Select a subset of rows using the .loc method.
data.iloc[796]
# Out:
# Unnamed: 0                 796
# City                 Bhavnagar
# Country                  India
# Population (2024)       751493
# Population (2023)       737128
# Growth Rate             0.0195
# Name: 796, dtype: object

# %%
data.loc[4,'City']
# Out:
# 'Sao Paulo'

# %%
#Filter rows based on a condition.
new_data=data[(data['Growth Rate']>0.0263) & (data["Population (2023)"]<2000000)]
new_data
# Out:
#      Unnamed: 0          City     Country  Population (2024)  \
# 255         255          Lome        Togo            2042734
# 268         268    Benin City     Nigeria            1972558
# 272         272       Can Tho     Vietnam            1938915
# 275         275      Quanzhou       China            1920733
# 276         276        Matola  Mozambique            1915035
# ..          ...           ...         ...                ...
# 786         786   Nay Pyi Taw     Myanmar             757823
# 787         787        Tamale       Ghana             757506
# 791         791  Zhangjiagang       China             755752
# 794         794         Amara        Iraq             753708
# 798         798        Huambo      Angola             751297
#
#      Population (2023)  Growth Rate
# 255            1981615       0.0308
# 268            1904631       0.0357
# 272            1865172       0.0395
# 275            1869994       0.0271
# 276            1852405       0.0338
# ...

# %%
#Group the DataFrame by a specific column and calculate the mean of each group.
grouped_data=data.groupby("Country")

# %%
mean=grouped_data["Population (2024)"].mean()
print(mean)
# Out:
# Country
# Afghanistan    4.728384e+06
# Algeria        1.951442e+06
# Angola         2.336443e+06
# Argentina      3.677088e+06
# Armenia        1.097542e+06
#                    ...
# Venezuela      1.564168e+06
# Vietnam        3.466374e+06
# Yemen          1.413566e+06
# Zambia         2.058284e+06
# Zimbabwe       1.603201e+06
# Name: Population (2024), Length: 132, dtype: float64

# %%
grouped=data.groupby('City')
data2=grouped["Population (2024)"].median()
print(data2)
# Out:
# City
# Aba              1230407.0
# Abidjan          5866704.0
# Abomey Calavi    1314916.0
# Abu Dhabi        1593284.0
# Abuja            4025735.0
#                    ...
# Zhuzhou          1277238.0
# Zibo             2828435.0
# Zigong            779684.0
# Zunyi            1406091.0
# Zurich           1443349.0
# Name: Population (2024), Length: 797, dtype: float64

# %%
#Group the DataFrame by multiple columns and calculate the sum of each group.
data3=data.groupby(["Country","City"])
data4=data3["Population (2023)"].sum()
print(data4)
# Out:
# Country      City
# Afghanistan  Kabul       4588666
# Algeria      Algiers     2901810
#              Oran         935947
# Angola       Benguela     809468
#              Cabinda      904676
#                           ...
# Yemen        Sanaa       3292497
#              Taiz         940600
# Zambia       Kitwe        762981
#              Lusaka      3181250
# Zimbabwe     Harare      1578128
# Name: Population (2023), Length: 800, dtype: int64

# %%
#Use the agg method to apply multiple aggregation functions to grouped data.

data3=data.groupby(["Country","City"])
data4=data3["Population (2023)"].agg(['sum', 'mean', 'std', 'median','min','max'])
print(data4)
# Out:
#                           sum       mean  std     median      min      max
# Country     City
# Afghanistan Kabul     4588666  4588666.0  NaN  4588666.0  4588666  4588666
# Algeria     Algiers   2901810  2901810.0  NaN  2901810.0  2901810  2901810
#             Oran       935947   935947.0  NaN   935947.0   935947   935947
# Angola      Benguela   809468   809468.0  NaN   809468.0   809468   809468
#             Cabinda    904676   904676.0  NaN   904676.0   904676   904676
# ...                       ...        ...  ...        ...      ...      ...
# Yemen       Sanaa     3292497  3292497.0  NaN  3292497.0  3292497  3292497
#             Taiz       940600   940600.0  NaN   940600.0   940600   940600
# Zambia      Kitwe      762981   762981.0  NaN   762981.0   762981   762981
#             Lusaka    3181250  3181250.0  NaN  3181250.0  3181250  3181250
# Zimbabwe    Harare    1578128  1578128.0  NaN  1578128.0  1578128  1578128
#
# [800 rows x 6 columns]

# %%
#Calculate the size of each group.
grouped=data.groupby('City')
print(grouped.size())
# Out:
# City
# Aba              1
# Abidjan          1
# Abomey Calavi    1
# Abu Dhabi        1
# Abuja            1
#                 ..
# Zhuzhou          1
# Zibo             1
# Zigong           1
# Zunyi            1
# Zurich           1
# Length: 797, dtype: int64

# %%
#Calculate the size of each group.
grouped=data.groupby(['City',"Country"])
grouped3=grouped["Population (2023)"].agg(["sum", "min", "max"])
print(grouped3)
print(grouped.size())
# Out:
#                                         sum      min      max
# City          Country
# Aba           Nigeria               1188803  1188803  1188803
# Abidjan       Ivory Coast           5686350  5686350  5686350
# Abomey Calavi Benin                 1252890  1252890  1252890
# Abu Dhabi     United Arab Emirates  1566999  1566999  1566999
# Abuja         Nigeria               3839646  3839646  3839646
# ...                                     ...      ...      ...
# Zhuzhou       China                 1254519  1254519  1254519
# Zibo          China                 2780142  2780142  2780142
# Zigong        China                  768075   768075   768075
# Zunyi         China                 1376453  1376453  1376453
# Zurich        Switzerland           1431538  1431538  1431538
#
# [800 rows x 3 columns]
# City           Country
# Aba            Nigeria                 1
# Abidjan        Ivory Coast             1
# Abomey Calavi  Benin                   1
# ...

# %%
#Select rows based on multiple conditions.
data3=data[(data["Country"]=="India") & (data["Population (2024)"]==751493) & (data["Population (2023)"]==737128	)]
data3
# Out:
#      Unnamed: 0       City Country  Population (2024)  Population (2023)  \
# 796         796  Bhavnagar   India             751493             737128
#
#      Growth Rate
# 796       0.0195

# %%
data4=data[(data["Country"]=="India") & (data["Growth Rate"]>0.0021) ]
data4
# Out:
#      Unnamed: 0            City Country  Population (2024)  Population (2023)  \
# 1             1           Delhi   India           33807403           32941309
# 8             8          Mumbai   India           21673149           21296517
# 16           16         Kolkata   India           15570786           15332793
# 21           21       Bangalore   India           14008262           13607800
# 25           25         Chennai   India           12053697           11776147
# ..          ...             ...     ...                ...                ...
# 762         762        Malegaon   India             781925             764628
# 769         769        Tirupati   India             775455             752744
# 781         781       Mangalore   India             763312             749073
# 792         792  Nanded Waghala   India             755577             738552
# 796         796       Bhavnagar   India             751493             737128
#
#      Growth Rate
# ...

# %%
#Use the query method to filter rows.
# The query method is used to filter the DataFrame based on the specified conditions.
# Conditions are specified as a string inside the query method.
# Column names containing spaces or special characters are enclosed in backticks (`).
data_new=data.query('`Growth Rate` >0.0302 and `Country`=="China"')
data_new
# Out:
#      Unnamed: 0            City Country  Population (2024)  Population (2023)  \
# 45           45          Suzhou   China            8350625            8074031
# 162         162          Huaian   China            3071048            2979893
# 233         233          Putian   China            2250104            2176022
# 236         236      Wuhu Anhui   China            2195262            2124797
# 308         308          Suqian   China            1726327            1664968
# 321         321          Anyang   China            1693375            1642347
# 361         361         Ganzhou   China            1508037            1459678
# 373         373         Jiaxing   China            1470917            1424982
# 384         384         Liuyang   China            1428802            1373523
# 385         385           Liuan   China            1427894            1378077
# 438         438          Jinhua   China            1296065            1257941
# ...

# %%
#Use isin to filter rows based on a list of values

# %%
#Select specific columns and rename them.
data=data.rename(columns={"City":"Cities"})
data=data.rename(columns={"Unnamed: 0": "Serial Num"})
data
# Out:
#      Serial Num          Cities         Country  Population (2024)  \
# 0             0           Tokyo           Japan           37115035
# 1             1           Delhi           India           33807403
# 2             2        Shanghai           China           29867918
# 3             3           Dhaka      Bangladesh           23935652
# 4             4       Sao Paulo          Brazil           22806704
# ..          ...             ...             ...                ...
# 796         796       Bhavnagar           India             751493
# 797         797       Sheffield  United Kingdom             751303
# 798         798          Huambo          Angola             751297
# 799         799  Ribeirao Preto          Brazil             750174
# 800         800       Panzhihua           China             750036
#
#      Population (2023)  Growth Rate
# 0             37194105      -0.0021
# 1             32941309       0.0263
# 2             29210808       0.0225
# ...

# %%
data
# Out:
#      Serial Num          Cities         Country  Population (2024)  \
# 0             0           Tokyo           Japan           37115035
# 1             1           Delhi           India           33807403
# 2             2        Shanghai           China           29867918
# 3             3           Dhaka      Bangladesh           23935652
# 4             4       Sao Paulo          Brazil           22806704
# ..          ...             ...             ...                ...
# 796         796       Bhavnagar           India             751493
# 797         797       Sheffield  United Kingdom             751303
# 798         798          Huambo          Angola             751297
# 799         799  Ribeirao Preto          Brazil             750174
# 800         800       Panzhihua           China             750036
#
#      Population (2023)  Growth Rate
# 0             37194105      -0.0021
# 1             32941309       0.0263
# 2             29210808       0.0225
# ...

# %%
#Use isin to filter rows based on a list of values.
asian_countries=["India","China","Japan","Bangladesh"]
data4=data[data["Country"].isin(asian_countries)]
data4
# Out:
#      Serial Num            Cities     Country  Population (2024)  \
# 0             0             Tokyo       Japan           37115035
# 1             1             Delhi       India           33807403
# 2             2          Shanghai       China           29867918
# 3             3             Dhaka  Bangladesh           23935652
# 7             7           Beijing       China           22189082
# ..          ...               ...         ...                ...
# 791         791      Zhangjiagang       China             755752
# 792         792    Nanded Waghala       India             755577
# 793         793  Xianyang Shaanxi       China             754446
# 796         796         Bhavnagar       India             751493
# 800         800         Panzhihua       China             750036
#
#      Population (2023)  Growth Rate
# 0             37194105      -0.0021
# 1             32941309       0.0263
# 2             29210808       0.0225
# 3             23209616       0.0313
# ...
