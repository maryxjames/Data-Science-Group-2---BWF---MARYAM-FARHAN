# %% [markdown]
# # 🔴 Task 16: Introduction to Matplotlib (basic plots: line, scatter, bar)

# %% [markdown]
# ### Basic Plots:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x= list(range(0,10))
y=list(range(-10,0))
plt.plot(x,y, color="red")
plt.title("plotting a graph")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
a=[0,49,70,-59]
b=[-60,90,23,45]
plt.plot(a,b)

# %%
a=[20,60,50,20]
b=[30,20,90,30]

plt.title("creating a triangle")
plt.plot(a,b)

# %%
a=[90,110,145,165,170]

b=[117,106,90,156,190]
c=[112,890.567,165,170]
plt.plot(a, label="Company 1")
plt.plot(b, label="Company 2")
plt.plot(c, label="Company 3")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
x_data=np.random.randint(2,30,25)
y_data=np.random.randint(0,50,25)
plt.scatter(x_data,y_data, marker="*", color="black")
plt.title("Scatter Plot", color="purple", font="Arial")
plt.show()

# %% [markdown]
# ## PIE CHARTS

# %%
votes=[120,56,70,80,34]
candidates=["Labour Party", "Conservative Party","The Nationals", "The Commoners", "Independents"]
plt.pie(votes, labels=None)
plt.legend(labels=candidates, loc="lower right")
plt.show()

# %%
votes=[120,56,70,80,34]
candidates=["Labour Party", "Conservative Party","The Nationals", "The Commoners", "Independents"]
plt.pie(votes, labels=candidates)

plt.show()

# %% [markdown]
# ## Bar Charts

# %%
a=[20,30,35,90,80,50,70]
b=[34,70,45,78,34,20,35]
plt.bar(a,b, color="r")
# Out:
# <BarContainer object of 7 artists>

# %%
a=[20,30,35,90,80,50,70]
b=[34,70,45,78,34,20,35]
plt.barh(a,b, color="yellow")
# Out:
# <BarContainer object of 7 artists>

# %%
gas=pd.read_csv("gas prices.csv")
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
gas=pd.read_csv("gas prices.csv")


gas.loc[0,"Australia"]=1.20
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990       1.20    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.plot(gas.Year, gas.UK, color="r")
plt.plot(gas.Year, gas.France, color="b")
plt.xlabel("Year")
plt.ylabel("Gas Prices")
plt.title("Gas Prices Over the Years", color="blue", font="Georgia")
plt.legend(labels=["UK", "France"], loc="upper left")
plt.show()

# %%
#used chatgpt for the background
fig, ax = plt.subplots()
fig.patch.set_facecolor('lightgrey')
ax.set_facecolor('grey')
plt.title("GAS PRICES ALL AROUND THE GLOBLE", color="black", fontname="Arial", fontweight="bold")
data={"USA":gas['USA'].sum(), "UK": gas["UK"].sum(),"Australia":gas["Australia"].sum(), "France":gas["France"].sum()}
values=list(data.values())
labels=list(data.keys())
plt.pie(values, autopct= '%1.1f%%')

plt.legend(labels=labels,loc="upper right")



plt.show()

# %%
#Explode a slice of the pie chart.
fig, ax = plt.subplots()
fig.patch.set_facecolor('lightgrey')
ax.set_facecolor('grey')
plt.title("GAS PRICES ALL AROUND THE GLOBLE", color="black", fontname="Arial", fontweight="bold")
data={"USA":gas['USA'].sum(), "UK": gas["UK"].sum(),"Australia":gas["Australia"].sum(), "France":gas["France"].sum()}
values=list(data.values())
labels=list(data.keys())
plt.pie(values, autopct= '%1.1f%%', explode=[0,0,0.1,0.2])

plt.legend(labels=labels,loc="upper right")



plt.show()

# %%
gas_price=[gas.USA.sum(), gas.UK.sum(), gas.France.sum(),gas.Australia.sum(),gas.Germany.sum()]
countries=["USA", "UK", "France", "Australia", "Germany"]
gas_price
countries
# Out:
# ['USA', 'UK', 'France', 'Australia', 'Germany']

# %%
plt.title("TOTAL GAS PRICES OVER THE YEARS", fontweight="bold", color="r")
plt.bar(countries, gas_price, color="g")
plt.xlabel("COUNTRIES", color="b")
plt.ylabel("TOTAL PRICE OVER THE YEARS", color="darkblue")
plt.show()

# %%
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.scatter(gas.Year,gas.Australia, marker="*")
plt.scatter(gas.Year,gas.France, marker="_", color="r")
plt.scatter(gas.Year,gas.UK, marker="+")
plt.scatter(gas.Year,gas.USA)
plt.title("GAS PRICES AROUND THE GLOBE OVER THE YEARS", fontweight="bold")
plt.ylabel("gas prices over the years")
plt.xlabel("Years")
countries2=["USA", "UK", "France", "Australia"]
plt.legend(labels=countries2, loc="upper left")
plt.show()

# %%
plt.title("TOTAL GAS PRICES OVER THE YEARS", fontweight="bold", color="r")
plt.barh(countries, gas_price, color="blue")
plt.ylabel("COUNTRIES", color="b")
plt.xlabel("TOTAL PRICE OVER THE YEARS", color="darkblue")
plt.show()
