# %% [markdown]
# # 🔴 Regression Models using scikit-learn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
import seaborn as sns

# %%
from sklearn import datasets,linear_model
from sklearn.metrics import mean_squared_error

# %%
diabetes= datasets.load_diabetes()

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
diabetes_X = diabetes.data[:,np.newaxis, 2]
diabetes_X
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %%
diabetes_X_train = diabetes_X[:-30]
diabetes_X_test = diabetes_X[-30:]

# %%
diabetes_y_train = diabetes.target[:-30]
diabetes_y_test = diabetes.target[-30:]

# %%
#x=feature, y=label
model=linear_model.LinearRegression()
model.fit(diabetes_X_train,diabetes_y_train)
diabetes_ypredict= model.predict(diabetes_X_test)

# %%
# sum of squared error average
#(predicted-actual)^2 + sum of all the values /num
print("Mean squared erros is :", mean_squared_error(diabetes_y_test,diabetes_ypredict))
print("Weights:", model.coef_)
print("Intercept:",model.intercept_)
# Out:
# Mean squared erros is : 3035.060115291269
# Weights: [941.43097333]
# Intercept: 153.39713623331644

# %%
plt.scatter(diabetes_X_test,diabetes_y_test)
plt.plot(diabetes_X_test,diabetes_ypredict, color="r")
plt.show()
